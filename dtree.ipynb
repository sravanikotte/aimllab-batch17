# %%
import pandas as pd
import matplotlib.pyplot as plt

d=pd.read_csv('/content/pokemon_alopez247.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(d)
# Out:
#      Total   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  \
# 0      318   45      49       49      65      65     45           1
# 1      405   60      62       63      80      80     60           1
# 2      525   80      82       83     100     100     80           1
# 3      309   39      52       43      60      50     65           1
# 4      405   58      64       58      80      65     80           1
# ..     ...  ...     ...      ...     ...     ...    ...         ...
# 716    680  126     131       95     131      98     99           6
# 717    600  108     100      121      81      95     95           6
# 718    600   50     100      150     100     150     50           6
# 719    600   80     110       60     150     130     70           6
# 720    600   80     110      120     130      90     70           6
#
#      hasGender  Pr_Male  hasMegaEvolution  Height_m  Weight_kg  Catch_Rate  \
# 0            1    0.875                 0      0.71        6.9          45
# 1            1    0.875                 0      0.99       13.0          45
# 2            1    0.875                 1      2.01      100.0          45
# 3            1    0.875                 0      0.61        8.5          45
# 4            1    0.875                 0      1.09       19.0          45
# ..         ...      ...               ...       ...        ...         ...
# 716          0      NaN                 0      5.79      203.0          45
# 717          0      NaN                 0      5.00      305.0           3
# 718          0      NaN                 1      0.71        8.8           3
# 719          0      NaN                 0      0.51        9.0           3
# 720          0      NaN                 0      1.70      195.0           3
#
#      isLegendary
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 716            1
# 717            1
# 718            1
# 719            1
# 720            1
#
# [721 rows x 15 columns]

# %%
print(d.isna())
print(d.isnull())
# Out:
#      Total     HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  \
# 0    False  False   False    False   False   False  False       False
# 1    False  False   False    False   False   False  False       False
# 2    False  False   False    False   False   False  False       False
# 3    False  False   False    False   False   False  False       False
# 4    False  False   False    False   False   False  False       False
# ..     ...    ...     ...      ...     ...     ...    ...         ...
# 716  False  False   False    False   False   False  False       False
# 717  False  False   False    False   False   False  False       False
# 718  False  False   False    False   False   False  False       False
# 719  False  False   False    False   False   False  False       False
# 720  False  False   False    False   False   False  False       False
#
#      hasGender  Pr_Male  hasMegaEvolution  Height_m  Weight_kg  Catch_Rate  \
# 0        False    False             False     False      False       False
# 1        False    False             False     False      False       False
# 2        False    False             False     False      False       False
# 3        False    False             False     False      False       False
# 4        False    False             False     False      False       False
# ..         ...      ...               ...       ...        ...         ...
# 716      False     True             False     False      False       False
# 717      False     True             False     False      False       False
# 718      False     True             False     False      False       False
# 719      False     True             False     False      False       False
# 720      False     True             False     False      False       False
#
#      isLegendary
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 716        False
# 717        False
# 718        False
# 719        False
# 720        False
#
# [721 rows x 15 columns]
#      Total     HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  \
# 0    False  False   False    False   False   False  False       False
# 1    False  False   False    False   False   False  False       False
# 2    False  False   False    False   False   False  False       False
# 3    False  False   False    False   False   False  False       False
# 4    False  False   False    False   False   False  False       False
# ..     ...    ...     ...      ...     ...     ...    ...         ...
# 716  False  False   False    False   False   False  False       False
# 717  False  False   False    False   False   False  False       False
# 718  False  False   False    False   False   False  False       False
# 719  False  False   False    False   False   False  False       False
# 720  False  False   False    False   False   False  False       False
#
#      hasGender  Pr_Male  hasMegaEvolution  Height_m  Weight_kg  Catch_Rate  \
# 0        False    False             False     False      False       False
# 1        False    False             False     False      False       False
# 2        False    False             False     False      False       False
# 3        False    False             False     False      False       False
# 4        False    False             False     False      False       False
# ..         ...      ...               ...       ...        ...         ...
# 716      False     True             False     False      False       False
# 717      False     True             False     False      False       False
# 718      False     True             False     False      False       False
# 719      False     True             False     False      False       False
# 720      False     True             False     False      False       False
#
#      isLegendary
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 716        False
# 717        False
# 718        False
# 719        False
# 720        False
#
# [721 rows x 15 columns]

# %%
print(d[4:9])
# Out:
#    Total  HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  hasGender  \
# 4    405  58      64       58      80      65     80           1          1
# 5    534  78      84       78     109      85    100           1          1
# 6    314  44      48       65      50      64     43           1          1
# 7    405  59      63       80      65      80     58           1          1
# 8    530  79      83      100      85     105     78           1          1
#
#    Pr_Male  hasMegaEvolution  Height_m  Weight_kg  Catch_Rate  isLegendary
# 4    0.875                 0      1.09       19.0          45            0
# 5    0.875                 1      1.70       90.5          45            0
# 6    0.875                 0      0.51        9.0          45            0
# 7    0.875                 0      0.99       22.5          45            0
# 8    0.875                 1      1.60       85.5          45            0

# %%
Data=pd.read_csv("/content/pokemon_alopez247.csv")
x1=Data['Total']
x2=Data['HP']
x3=Data['Attack']
x4=Data['Defense']
x5=Data['Sp_Atk']
x6=Data['Sp_Def']
x7=Data['Speed']
x8=Data['Generation']
x9=Data['hasGender']
x10=Data['Pr_Male']
x11=Data['hasMegaEvolution']
x12=Data['Height_m']
x13=Data['Weight_kg']
x14=['Catch_Rate']
y=Data['isLegendary']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x=Data.iloc[:,0:13]
x1=x.fillna(0)
print(y)
print(x1.isnull().count())
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 716    1
# 717    1
# 718    1
# 719    1
# 720    1
# Name: isLegendary, Length: 721, dtype: int64
# Total               721
# HP                  721
# Attack              721
# Defense             721
# Sp_Atk              721
# Sp_Def              721
# Speed               721
# Generation          721
# hasGender           721
# Pr_Male             721
# hasMegaEvolution    721
# Height_m            721
# Weight_kg           721
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=40,random_state=True)

# %%
print(y_train,y_test)
# Out:
# 148    0
# 329    0
# 684    0
# 620    0
# 677    0
#       ..
# 645    1
# 715    1
# 72     0
# 235    0
# 37     0
# Name: isLegendary, Length: 681, dtype: int64 59     0
# 60     0
# 214    0
# 638    1
# 8      0
# 101    0
# 474    0
# 161    0
# 406    0
# 509    0
# 683    0
# 419    0
# 517    0
# 443    0
# 673    0
# 502    0
# 628    0
# 248    1
# 496    0
# 484    1
# 61     0
# 607    0
# 681    0
# 675    0
# 261    0
# 181    0
# 655    0
# 277    0
# 412    0
# 452    0
# 23     0
# 69     0
# 289    0
# 516    0
# 224    0
# 437    0
# 436    0
# 507    0
# 510    0
# 397    0
# Name: isLegendary, dtype: int64

# %%
dt=DecisionTreeClassifier()
cc=dt.fit(x_train,y_train)

# %%
yp=cc.predict(x_test)

# %%
print(accuracy_score(yp,y_test))
# Out:
# 0.975

# %%
from sklearn import tree
tree.plot_tree(cc,filled=True)
# Out:
# [Text(0.5, 0.9583333333333334, 'x[0] <= 573.5\ngini = 0.118\nsamples = 681\nvalue = [638, 43]'),
#  Text(0.4, 0.875, 'gini = 0.0\nsamples = 623\nvalue = [623, 0]'),
#  Text(0.6, 0.875, 'x[8] <= 0.5\ngini = 0.383\nsamples = 58\nvalue = [15, 43]'),
#  Text(0.4, 0.7916666666666666, 'x[11] <= 1.65\ngini = 0.263\nsamples = 45\nvalue = [7, 38]'),
#  Text(0.3, 0.7083333333333334, 'x[12] <= 1.25\ngini = 0.484\nsamples = 17\nvalue = [7, 10]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4, 0.625, 'x[4] <= 132.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.3, 0.5416666666666666, 'x[3] <= 140.0\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.2, 0.4583333333333333, 'x[11] <= 0.25\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.1, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3, 0.375, 'x[6] <= 99.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.2, 0.2916666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4, 0.2916666666666667, 'x[12] <= 50.55\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.3, 0.20833333333333334, 'x[7] <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4, 0.125, 'x[0] <= 590.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.4583333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.5416666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5, 0.7083333333333334, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.8, 0.7916666666666666, 'x[1] <= 89.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.7, 0.7083333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9, 0.7083333333333334, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]')]

# %%
from sklearn import tree
plt.figure(figsize=(35,29))
tree.plot_tree(cc,filled=True)
# Out:
# [Text(0.5, 0.9583333333333334, 'x[0] <= 573.5\ngini = 0.118\nsamples = 681\nvalue = [638, 43]'),
#  Text(0.4, 0.875, 'gini = 0.0\nsamples = 623\nvalue = [623, 0]'),
#  Text(0.6, 0.875, 'x[8] <= 0.5\ngini = 0.383\nsamples = 58\nvalue = [15, 43]'),
#  Text(0.4, 0.7916666666666666, 'x[11] <= 1.65\ngini = 0.263\nsamples = 45\nvalue = [7, 38]'),
#  Text(0.3, 0.7083333333333334, 'x[12] <= 1.25\ngini = 0.484\nsamples = 17\nvalue = [7, 10]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4, 0.625, 'x[4] <= 132.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.3, 0.5416666666666666, 'x[3] <= 140.0\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.2, 0.4583333333333333, 'x[11] <= 0.25\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.1, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3, 0.375, 'x[6] <= 99.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.2, 0.2916666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4, 0.2916666666666667, 'x[12] <= 50.55\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.3, 0.20833333333333334, 'x[7] <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4, 0.125, 'x[0] <= 590.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.4583333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.5416666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5, 0.7083333333333334, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.8, 0.7916666666666666, 'x[1] <= 89.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.7, 0.7083333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9, 0.7083333333333334, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]')]

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=40,random_state=True)

# %%
print(y_train,y_test)
# Out:
# 148    0
# 329    0
# 684    0
# 620    0
# 677    0
#       ..
# 645    1
# 715    1
# 72     0
# 235    0
# 37     0
# Name: isLegendary, Length: 681, dtype: int64 59     0
# 60     0
# 214    0
# 638    1
# 8      0
# 101    0
# 474    0
# 161    0
# 406    0
# 509    0
# 683    0
# 419    0
# 517    0
# 443    0
# 673    0
# 502    0
# 628    0
# 248    1
# 496    0
# 484    1
# 61     0
# 607    0
# 681    0
# 675    0
# 261    0
# 181    0
# 655    0
# 277    0
# 412    0
# 452    0
# 23     0
# 69     0
# 289    0
# 516    0
# 224    0
# 437    0
# 436    0
# 507    0
# 510    0
# 397    0
# Name: isLegendary, dtype: int64

# %%
ss=SVC()

# %%
cc1=ss.fit(x_train,y_train)

# %%
yp=cc1.predict(x_test)

# %%
print(accuracy_score(yp,y_test))
# Out:
# 0.975
